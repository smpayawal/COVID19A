# %% [markdown]
# # COVID-19-Data-Analysis
#
# IBM Data Analyst Specialization Capstone
#
# ## EXECUTIVE SUMMARY
#
# - #### Most of affected people are aged 50-80+ years old.
#
# - #### NCR and CALABARZON are the most affected regions
#
#    - This is followed by Central Luzon, Central Visayas and Western Visayas
#    - Central Luzon top Calabarzon in Death cases
#    - BARMM is the lowest confirmed,active and death cases
#
# - #### Aged 20-40 years old take the top for confirmed, active and recovered cases
#
#    - While 0-14 years old remain the lowest
#
# - #### Male top the female in death cases while female top male in active cases
#
# ## INTRODUCTION
# - Understanding COVID-19 cases is imperative for the safety of everyone
# - The goal of this analysis is to understand the effect of the virus(COVID19) in every regions,ages and gender
# - This analysis is useful for strengthening our knowledge about how the virus can affect us
# - Two datasets from PSA PH and DOH PH are used for this purpose
#    - Demographic Data
#    - Covid19 Data Information
#
# ## METHODOLOGY
# - Data Collection
#    - The datasets were sourced online from PSA PH and DOH PH as it was made open-sourced for the public
#
# - Data Exploration
#    - The datasets contained information of the infected individual
#    - Explore missing values
#
# - Data Cleaning
#    - Remove unnecessary data
#
# - Data Visulization
#    - Using a different charts to draw some insights
#    - Use Tableau for more awesome Visualization

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
plt.style.use('ggplot')

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,10)

import seaborn as sns


df = pd.read_csv('DOH COVID Data Drop_ 20211005 - 04 Case Information.csv')

print(df.shape,'\n')

print(df.dtypes)
# Out:
# D:\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (2613070, 22)
#
# CaseCode              object
# Age                  float64
# AgeGroup              object
# Sex                   object
# DateSpecimen          object
# DateResultRelease     object
# DateRepConf           object
# DateDied              object
# DateRecover           object
# RemovalType           object
# Admitted              object
# RegionRes             object
# ProvRes               object
# CityMunRes            object
# CityMuniPSGC          object
# BarangayRes           object
# BarangayPSGC          object
# HealthStatus          object
# Quarantined           object
# DateOnset             object
# Pregnanttab           object
# ValidationStatus      object
# dtype: object

# %%
df.head()
# Out:
#   CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease DateRepConf  \
# 0  C907343  46.0  45 to 49  FEMALE   2020-05-12        2020-05-24  2020-05-28
# 1  C221714  26.0  25 to 29    MALE   2020-07-22        2020-07-24  2020-08-01
# 2  C902043  32.0  30 to 34  FEMALE   2020-06-25        2020-07-06  2020-07-08
# 3  C168921  22.0  20 to 24  FEMALE   2020-07-16        2020-07-18  2020-07-22
# 4  C727313  21.0  20 to 24    MALE   2020-08-03        2020-08-06  2020-08-09
#
#   DateDied DateRecover RemovalType  ... ProvRes        CityMunRes  \
# 0      NaN         NaN   RECOVERED  ...     NaN               NaN
# 1      NaN         NaN   RECOVERED  ...     NCR    CITY OF MANILA
# 2      NaN  2020-07-13   RECOVERED  ...     NaN               NaN
# 3      NaN         NaN   RECOVERED  ...     NCR               NaN
# 4      NaN         NaN   RECOVERED  ...     NCR  CITY OF MARIKINA
#
#   CityMuniPSGC BarangayRes BarangayPSGC HealthStatus Quarantined DateOnset  \
# 0          NaN         NaN          NaN    RECOVERED          NO       NaN
# 1  PH133910000         NaN          NaN    RECOVERED          NO       NaN
# 2          NaN         NaN          NaN    RECOVERED          NO       NaN
# 3          NaN         NaN          NaN    RECOVERED          NO       NaN
# 4  PH137402000         NaN          NaN    RECOVERED          NO       NaN
#
#   Pregnanttab                                   ValidationStatus
# 0          NO  Removal Type is "Recovered", but no Recovered ...
# 1         NaN  Health Status is "Recovered", but no Date Reco...
# 2          NO                                                NaN
# 3          NO  Health Status is "Recovered", but no Date Reco...
# 4         NaN  Removal Type is "Recovered", but no Recovered ...
#
# [5 rows x 22 columns]

# %%
sns.heatmap(df[df.columns].isnull())
# Out:
# <AxesSubplot:>

# %%
for column in df.columns:
    print(f'{column} - {round(np.mean(df[column].isnull()) * 100)}%')

# %%
df.dropna(thresh=df.shape[0]*0.7, how='all', axis=1, inplace = True)
df.head()
# Out:
#   CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease DateRepConf  \
# 0  C907343  46.0  45 to 49  FEMALE   2020-05-12        2020-05-24  2020-05-28
# 1  C221714  26.0  25 to 29    MALE   2020-07-22        2020-07-24  2020-08-01
# 2  C902043  32.0  30 to 34  FEMALE   2020-06-25        2020-07-06  2020-07-08
# 3  C168921  22.0  20 to 24  FEMALE   2020-07-16        2020-07-18  2020-07-22
# 4  C727313  21.0  20 to 24    MALE   2020-08-03        2020-08-06  2020-08-09
#
#   RemovalType                     RegionRes ProvRes        CityMunRes  \
# 0   RECOVERED                           NCR     NaN               NaN
# 1   RECOVERED                           NCR     NCR    CITY OF MANILA
# 2   RECOVERED  Region VIII: Eastern Visayas     NaN               NaN
# 3   RECOVERED                           NCR     NCR               NaN
# 4   RECOVERED                           NCR     NCR  CITY OF MARIKINA
#
#   CityMuniPSGC BarangayRes BarangayPSGC HealthStatus Quarantined  \
# 0          NaN         NaN          NaN    RECOVERED          NO
# 1  PH133910000         NaN          NaN    RECOVERED          NO
# 2          NaN         NaN          NaN    RECOVERED          NO
# 3          NaN         NaN          NaN    RECOVERED          NO
# 4  PH137402000         NaN          NaN    RECOVERED          NO
#
#                                     ValidationStatus
# 0  Removal Type is "Recovered", but no Recovered ...
# 1  Health Status is "Recovered", but no Date Reco...
# 2                                                NaN
# 3  Health Status is "Recovered", but no Date Reco...
# 4  Removal Type is "Recovered", but no Recovered ...

# %%
df.drop(['DateSpecimen', 'DateResultRelease', 'RemovalType', 'ProvRes', 'CityMuniPSGC', 'BarangayRes', 'BarangayPSGC', 'ValidationStatus'], axis = 1, inplace = True)
df
# Out:
#           CaseCode   Age  AgeGroup     Sex DateRepConf  \
# 0          C907343  46.0  45 to 49  FEMALE  2020-05-28
# 1          C221714  26.0  25 to 29    MALE  2020-08-01
# 2          C902043  32.0  30 to 34  FEMALE  2020-07-08
# 3          C168921  22.0  20 to 24  FEMALE  2020-07-22
# 4          C727313  21.0  20 to 24    MALE  2020-08-09
# ...            ...   ...       ...     ...         ...
# 2613065  C48945534  11.0  10 to 14    MALE  2021-06-21
# 2613066  C14618667  45.0  45 to 49    MALE  2021-05-16
# 2613067  C71738420  37.0  35 to 39  FEMALE  2021-05-25
# 2613068  C12500660  58.0  55 to 59  FEMALE  2021-08-09
# 2613069  C91347666  29.0  25 to 29  FEMALE  2021-09-22
#
#                             RegionRes        CityMunRes HealthStatus  \
# 0                                 NCR               NaN    RECOVERED
# 1                                 NCR    CITY OF MANILA    RECOVERED
# 2        Region VIII: Eastern Visayas               NaN    RECOVERED
# 3                                 NCR               NaN    RECOVERED
# 4                                 NCR  CITY OF MARIKINA    RECOVERED
# ...                               ...               ...          ...
# 2613065         Region IV-B: MIMAROPA            QUEZON    RECOVERED
# 2613066         Region IV-B: MIMAROPA            TAYTAY    RECOVERED
# 2613067         Region IV-B: MIMAROPA            TAYTAY    RECOVERED
# 2613068         Region IV-B: MIMAROPA            CULION    RECOVERED
# 2613069         Region IV-B: MIMAROPA          ODIONGAN    RECOVERED
#
#         Quarantined
# 0                NO
# 1                NO
# 2                NO
# 3                NO
# 4                NO
# ...             ...
# 2613065         YES
# 2613066         YES
# 2613067         YES
# 2613068          NO
# 2613069          NO
#
# [2613070 rows x 9 columns]

# %%
cases = df.groupby(['HealthStatus']).size()
cases
# Out:
# HealthStatus
# ASYMPTOMATIC      11785
# CRITICAL           1275
# DIED              38828
# MILD              81201
# MODERATE           5823
# RECOVERED       2471165
# SEVERE             2993
# dtype: int64

# %%
pd.DataFrame({'Confirmed': [cases.sum()],
             'Deaths': [cases[2]],
             'Recovered': [cases[5]],
             'Active': [cases[[0,1,3,4,6]].sum()]})
# Out:
#    Confirmed  Deaths  Recovered  Active
# 0    2613070   38828    2471165  103077

# %%
regional = df.groupby(['RegionRes', 'HealthStatus']).size()
regional
# Out:
# RegionRes                 HealthStatus
# BARMM                     ASYMPTOMATIC       82
#                           CRITICAL            2
#                           DIED              395
#                           MILD              529
#                           MODERATE           40
#                                           ...
# Region XII: SOCCSKSARGEN  DIED              955
#                           MILD             1431
#                           MODERATE          412
#                           RECOVERED       52201
#                           SEVERE             82
# Length: 126, dtype: int64

# %%
regional_case = []
for region in df.RegionRes.dropna().unique():
    regional_case.append({'Confirmed': regional[region].sum(), 'Deaths': regional[region][2],
                          'Recovered': regional[region][5], 'Active': regional[region][[0,1,3,4,6]].sum()}#,
                          #ignore_index = True)
         )

# %%
regional_cases = pd.DataFrame(regional_case, index = [df.RegionRes.dropna().unique()])
regional_cases.sort_values('Confirmed', ascending = False, inplace = True)

# %%
regional_cases
# Out:
#                                 Confirmed  Deaths  Recovered  Active
# NCR                                819080    9679     787234   22167
# Region IV-A: CALABARZON            470993    4853     451496   14644
# Region III: Central Luzon          261658    5275     245438   10945
# Region VII: Central Visayas        145103    3967     136921    4215
# Region VI: Western Visayas         138789    2825     129907    6057
# Region II: Cagayan Valley          114192    1902     105313    6977
# Region XI: Davao Region             97629    1551      91596    4482
# Region I: Ilocos Region             92532    1550      83093    7889
# Region X: Northern Mindanao         80971     904      77572    2495
# CAR                                 76570    1129      69633    5808
# Region XII: SOCCSKSARGEN            55174     955      52201    2018
# Region VIII: Eastern Visayas        50689     601      45301    4787
# CARAGA                              45731     964      42402    2365
# Region V: Bicol Region              43447     680      39721    3046
# Region IX: Zamboanga Peninsula      42867     831      39667    2369
# Region IV-B: MIMAROPA               29836     688      27269    1879
# ROF                                 27063      71      26848     144
# BARMM                               17363     395      16298     670

# %%
regional_cases.sort_values('Confirmed')['Confirmed'].plot(kind = 'barh',color="darkcyan")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Confirmed Cases by Region",fontsize=20)
plt.grid(alpha=0.3)

# %%
regional_cases.sort_values('Deaths')['Deaths'].plot(kind = 'barh',color="crimson")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Death Cases by Region",fontsize=20)
plt.grid(alpha=0.3)

# %%
regional_cases.sort_values('Recovered')['Recovered'].plot(kind = 'barh',color="limegreen")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Recovered Cases by Region",fontsize=20)
plt.grid(alpha=0.3)

# %%
regional_cases.sort_values('Active')['Active'].plot(kind = 'barh',color="darkorange")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Active Cases by Region",fontsize=20)
plt.grid(alpha=0.3)

# %%
regional_cases.corr().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col0,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col2,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col1,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col0,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col2,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col3{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col1{
#             background-color:  #fc997a;
#             color:  #000000;
#         }#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col3{
#             background-color:  #fc8f6f;
#             color:  #000000;
#         }#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col0,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col2,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col3,#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col1{
#             background-color:  #fca183;
#             color:  #000000;
#         }#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col3{
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col0{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col2{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }</style><table id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Recovered</th>        <th class="col_heading level0 col3" >Active</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42level0_row0" class="row_heading level0 row0" >Confirmed</th>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col1" class="data row0 col1" >0.951168</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col2" class="data row0 col2" >0.999949</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row0_col3" class="data row0 col3" >0.953582</td>
#             </tr>
#             <tr>
#                         <th id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42level0_row1" class="row_heading level0 row1" >Deaths</th>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col0" class="data row1 col0" >0.951168</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col2" class="data row1 col2" >0.949418</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row1_col3" class="data row1 col3" >0.924669</td>
#             </tr>
#             <tr>
#                         <th id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42level0_row2" class="row_heading level0 row2" >Recovered</th>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col0" class="data row2 col0" >0.999949</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col1" class="data row2 col1" >0.949418</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row2_col3" class="data row2 col3" >0.950722</td>
#             </tr>
#             <tr>
#                         <th id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42level0_row3" class="row_heading level0 row3" >Active</th>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col0" class="data row3 col0" >0.953582</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col1" class="data row3 col1" >0.924669</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col2" class="data row3 col2" >0.950722</td>
#                         <td id="T_67d5251e_26aa_11ec_ad78_c025e92d4b42row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
age_groups = df.groupby(['AgeGroup', 'HealthStatus']).size()
age_groups
# Out:
# AgeGroup  HealthStatus
# 0 to 4    ASYMPTOMATIC      324
#           CRITICAL           17
#           DIED              321
#           MILD             2278
#           MODERATE          105
#                           ...
# 80+       DIED             5223
#           MILD             2201
#           MODERATE          349
#           RECOVERED       37534
#           SEVERE            227
# Length: 119, dtype: int64

# %%
agegroup_case = []
for group in df.AgeGroup.dropna().unique():
    agegroup_case.append({'Confirmed': age_groups[group].sum(), 'Deaths': age_groups[group][2],
                          'Recovered': age_groups[group][5], 'Active': age_groups[group][[0,1,3,4,6]].sum()}#,
                          #ignore_index = True)
         )

# %%
ageGroup_cases = pd.DataFrame(agegroup_case, index = [df.AgeGroup.dropna().unique()])
ageGroup_cases.sort_values('Confirmed', ascending = False, inplace = True)

# %%
ageGroup_cases
# Out:
#           Confirmed  Deaths  Recovered  Active
# 25 to 29     364356     583     351983   11790
# 30 to 34     324686     818     312854   11014
# 20 to 24     267837     320     258415    9102
# 35 to 39     251305    1112     241425    8768
# 40 to 44     217705    1548     208410    7747
# 45 to 49     181398    2177     172411    6810
# 50 to 54     170404    3180     160465    6759
# 55 to 59     152649    4101     141734    6814
# 60 to 64     121256    5013     110670    5573
# 15 to 19     118626     166     113310    5150
# 65 to 69      90925    5367      80765    4793
# 10 to 14      81444      92      77525    3827
# 70 to 74      65930    5145      57170    3615
# 5 to 9        59907      50      57043    2814
# 0 to 4        57219     321      54119    2779
# 80+           45867    5223      37534    3110
# 75 to 79      38862    3595      32803    2464

# %%
ageGroup_cases.sort_values('Confirmed')['Confirmed'].plot(kind = 'barh',color="darkcyan")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Confirmed Cases by Age",fontsize=20)
plt.grid(alpha=0.3)

# %%
ageGroup_cases.sort_values('Deaths')['Deaths'].plot(kind = 'barh',color="crimson")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Death Cases by Age",fontsize=20)
plt.grid(alpha=0.3)

# %%
ageGroup_cases.sort_values('Recovered')['Recovered'].plot(kind = 'barh',color="limegreen")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Recovered Cases by Age",fontsize=20)
plt.grid(alpha=0.3)

# %%
ageGroup_cases.sort_values('Active')['Active'].plot(kind = 'barh',color="darkorange")

plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Cases",fontsize=18)
plt.title("Covid-19 Active Cases by Age",fontsize=20)
plt.grid(alpha=0.3)

# %%
ageGroup_cases.corr().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col0,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col2,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col1,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col0,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col2,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col3{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col1{
#             background-color:  #fff3ed;
#             color:  #000000;
#         }#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col3,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col3,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col0,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col2{
#             background-color:  #69000d;
#             color:  #f1f1f1;
#         }#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col0,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col2,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col3,#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col1{
#             background-color:  #fee8de;
#             color:  #000000;
#         }</style><table id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Recovered</th>        <th class="col_heading level0 col3" >Active</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42level0_row0" class="row_heading level0 row0" >Confirmed</th>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col1" class="data row0 col1" >-0.404451</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col2" class="data row0 col2" >0.999760</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row0_col3" class="data row0 col3" >0.992373</td>
#             </tr>
#             <tr>
#                         <th id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42level0_row1" class="row_heading level0 row1" >Deaths</th>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col0" class="data row1 col0" >-0.404451</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col2" class="data row1 col2" >-0.424286</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row1_col3" class="data row1 col3" >-0.317901</td>
#             </tr>
#             <tr>
#                         <th id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42level0_row2" class="row_heading level0 row2" >Recovered</th>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col0" class="data row2 col0" >0.999760</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col1" class="data row2 col1" >-0.424286</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row2_col3" class="data row2 col3" >0.989944</td>
#             </tr>
#             <tr>
#                         <th id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42level0_row3" class="row_heading level0 row3" >Active</th>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col0" class="data row3 col0" >0.992373</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col1" class="data row3 col1" >-0.317901</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col2" class="data row3 col2" >0.989944</td>
#                         <td id="T_69beac3e_26aa_11ec_89d4_c025e92d4b42row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
sex_groups = df.groupby(['Sex', 'HealthStatus']).size()
sex_groups
# Out:
# Sex     HealthStatus
# FEMALE  ASYMPTOMATIC       6107
#         CRITICAL            549
#         DIED              16995
#         MILD              43087
#         MODERATE           3046
#         RECOVERED       1228913
#         SEVERE             1378
# MALE    ASYMPTOMATIC       5678
#         CRITICAL            726
#         DIED              21833
#         MILD              38114
#         MODERATE           2777
#         RECOVERED       1242252
#         SEVERE             1615
# dtype: int64

# %%
sexgroup_case = []
for sex in df.Sex.dropna().unique():
    sexgroup_case.append({'Confirmed': sex_groups[sex].sum(), 'Deaths': sex_groups[sex][2],
                          'Recovered': sex_groups[sex][5], 'Active': sex_groups[sex][[0,1,3,4,6]].sum()}#,
                          #ignore_index = True)
         )

# %%
sexGroup_cases = pd.DataFrame(sexgroup_case, index = [df.Sex.dropna().unique()])
sexGroup_cases.sort_values('Confirmed', ascending = False, inplace = True)

# %%
sexGroup_cases
# Out:
#         Confirmed  Deaths  Recovered  Active
# MALE      1312995   21833    1242252   48910
# FEMALE    1300075   16995    1228913   54167

# %%
sexGroup_cases.loc[['FEMALE', 'MALE'], 'Confirmed']
# Out:
# FEMALE    1300075
# MALE      1312995
# Name: Confirmed, dtype: int64
